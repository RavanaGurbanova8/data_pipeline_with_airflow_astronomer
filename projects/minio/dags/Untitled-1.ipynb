# %%
import pandas as pd
df = pd.read_parquet("C:/Users/ravan/OneDrive/Desktop/dataa/combined_disease_2026-07-29.parquet")
df.head(5)
# Out:
#   pixel_id            datetime  risk_level  temperature  precipitation  \
# 0        5 2026-07-29 00:00:00        40.0        26.32            0.0
# 1        5 2026-07-29 01:00:00        40.0        25.41            0.0
# 2        5 2026-07-29 02:00:00        40.0        24.67            0.0
# 3        5 2026-07-29 03:00:00        40.0        24.05            0.0
# 4        5 2026-07-29 04:00:00        40.0        23.34            0.0
#
#    relative_humidity  leaf_wetness  final_risk   target               kind  \
# 0               45.0             0        40.0  disease  taprina_leaf_curl
# 1               47.0             0        40.0  disease  taprina_leaf_curl
# 2               51.0             0        40.0  disease  taprina_leaf_curl
# 3               55.0             0        40.0  disease  taprina_leaf_curl
# 4               58.0             0        40.0  disease  taprina_leaf_curl
#
#    risk_level_wt risk_level_mc  mc_weight
# 0            NaN          None        NaN
# ...

# %%
df.columns
# Out:
# Index(['pixel_id', 'datetime', 'risk_level', 'temperature', 'precipitation',
#        'relative_humidity', 'leaf_wetness', 'final_risk', 'target', 'kind',
#        'risk_level_wt', 'risk_level_mc', 'mc_weight'],
#       dtype='object')

# %%
df["risk_level_mc"].value_counts()
# Out:
# risk_level_mc
# No Infection Risk    1049328
# Name: count, dtype: int64

# %%
df['risk_level_mc'].dtypes
# Out:
# dtype('O')
